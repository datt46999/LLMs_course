# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %%
name_model = "mistralai/Mistral-7B-v0.1"
promt = ["the list colors: red, blue, green"]


quantization_config = BitsAndBytesConfig(load_in_4bit=True)
model = AutoModelForCausalLM.from_pretrained(name_model, device_map="auto", quantization_config=quantization_config)

# %%
prompt = ["a list of animal: cat, dog, fish"]

# %%
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1", padding_side="left")
model_inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# %%
generated_ids = model.generate(**model_inputs)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

# %% [markdown]
# # Generation Configuration

# %%
# show generation config
model.generation_config

# %%
model.generate(**model_inputs, num_beams=4, do_sample=True)

# %% [markdown]
# model_inputs = tokenizer(["I am a cat."], return_tensors="pt").to(model.device)

# %%
generated_ids = model.generate(**model_inputs)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

# %%
generated_ids = model.generate(**model_inputs, do_sample=True, temperature=0.7,top_p=0.9)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
